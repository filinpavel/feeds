# %%
# !pip install pandas_datareader
import pandas as pd
import pandas_datareader as pdr
import sys, datetime
# %matplotlib inline

# %%
t = datetime.datetime.now()
d = str(t).split()
delta = datetime.timedelta(days=120)
end = pd.to_datetime('{}'.format(d[0]))
start = pd.to_datetime(end-delta)
df = pdr.get_data_yahoo('MSFT',start,end)

# %%
df.info()
pdr.get_data_moex()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 84 entries, 2020-08-26 to 2020-12-23
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       84 non-null     float64
#  1   Low        84 non-null     float64
#  2   Open       84 non-null     float64
#  3   Close      84 non-null     float64
#  4   Volume     84 non-null     float64
#  5   Adj Close  84 non-null     float64
# dtypes: float64(6)
# memory usage: 4.6 KB

# %%
df[['Open','Close']].plot(figsize=(8,5))

# %%
df.Close.pct_change().plot(figsize=(8,5))

# %%
# !pip install geopandas
import geopandas
# Out:
# ...
#      |████████████████████████████████| 972kB 3.2MB/s
# ...
#      |████████████████████████████████| 6.5MB 18.1MB/s
# ...
#      |████████████████████████████████| 14.8MB 218kB/s
# ...

# %%
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))
world.plot(figsize=(16,10))

# %%
plt.style.use('dark_background')
world.plot(color='black', edgecolor='cyan',figsize=(16,10))

# %%
world.name[4]
# Out:
# 'United States of America'

# %%
loc = geopandas.tools.geocode(world.name[4])

# %%
loc
# Out:
#                      geometry                       address
# 0  POINT (-99.01830 39.50355)  United States, United States

# %%
import matplotlib.pyplot as plt
import numpy as np


from sklearn.datasets import make_blobs

X, Y=make_blobs(n_samples=500, centers=2,random_state=0, cluster_std=.4)

plt.scatter(X[:, 0], X[:, 1], c=Y, s=50)
plt.show()  

xfit=np.linspace(-1,3.5)

for m, b, d in [(1, 0.65, 0.33), (0.5, 1.6, 0.55), (-0.2, 2.9, 0.2)]:
  yfit = m * xfit + b
  plt.plot(xfit, yfit, '-k')

plt.fill_between(xfit, yfit - d, yfit + d, edgecolor='none',
color='#AAAAAA', alpha=0.4)
plt.xlim(-1, 3.5)
# Out:
# (-1.0, 3.5)
